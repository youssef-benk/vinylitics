# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load dataset

# %%
raw_tracks = pd.read_csv('raw_data/fma_metadata/raw_tracks.csv')
tracks = pd.read_csv('raw_data/fma_metadata/tracks.csv')
features = pd.read_csv('raw_data/fma_metadata/features.csv', header=[0,1,2,3])
echonest = pd.read_csv('raw_data/fma_metadata/echonest.csv')
# Out:
# /var/folders/x5/hq9bgtqd0xsd3m8vdl6z9n100000gn/T/ipykernel_89881/1717688320.py:2: DtypeWarning: Columns (0,1,5,6,8,12,18,20,21,22,24,33,34,38,39,44,47,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   tracks = pd.read_csv('raw_data/fma_metadata/tracks.csv')
# ...

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### tracks

# %%
raw_tracks.columns
# Out:
# Index(['track_id', 'album_id', 'album_title', 'album_url', 'artist_id',
#        'artist_name', 'artist_url', 'artist_website', 'license_image_file',
#        'license_image_file_large', 'license_parent_id', 'license_title',
#        'license_url', 'tags', 'track_bit_rate', 'track_comments',
#        'track_composer', 'track_copyright_c', 'track_copyright_p',
#        'track_date_created', 'track_date_recorded', 'track_disc_number',
#        'track_duration', 'track_explicit', 'track_explicit_notes',
#        'track_favorites', 'track_file', 'track_genres', 'track_image_file',
#        'track_information', 'track_instrumental', 'track_interest',
#        'track_language_code', 'track_listens', 'track_lyricist',
#        'track_number', 'track_publisher', 'track_title', 'track_url'],
#       dtype='object')

# %%
raw_tracks.sample(5)
# Out:
#         track_id  album_id        album_title  \
# 81750     118769   18188.0         Bon Voyage
# 11597      18465       NaN                NaN
# 17157      26309    5703.0       Baby Nettles
# 106424    150057   22377.0  Concert à Cave 12
# 97539     138521   20815.0         Sans album
#
#                                                 album_url  artist_id  \
# 81750   http://freemusicarchive.org/music/Podington_Be...       7168
# 11597                                                 NaN       4810
# 17157   http://freemusicarchive.org/music/Karl_Blau/Ba...       6484
# 106424  http://freemusicarchive.org/music/Crank_Sturge...      23751
# 97539   http://freemusicarchive.org/music/Charles_Prem...      17450
#
#                                 artist_name  \
# 81750                        Podington Bear
# 11597                           Aaron Moore
# 17157                             Karl Blau
# 106424  Crank Sturgeon & Olivier Di Placido
# ...

# %%
import json
eval(raw_tracks.track_genres[0])[0]['genre_title']
# Out:
# 'Hip-Hop'

# %%
# have the track genre as the genres title, and not as a dict into a list

# %% [markdown]
# ### Features

# %%
features
# Out:
#           feature chroma_cens                                          \
#        statistics    kurtosis
#            number          01        02        03        04        05
# 0               2    7.180653  5.230309  0.249321  1.347620  1.482478
# 1               3    1.888963  0.760539  0.345297  2.295201  1.654031
# 2               5    0.527563 -0.077654 -0.279610  0.685883  1.937570
# 3              10    3.702245 -0.291193  2.196742 -0.234449  1.367364
# 4              20   -0.193837 -0.198527  0.201546  0.258556  0.775204
# ...           ...         ...       ...       ...       ...       ...
# 106569     155316   -0.490129  0.463834  2.321970 -0.084352  1.662914
# 106570     155317   -0.461559 -0.229601 -0.496632 -0.422033  0.130612
# 106571     155318    0.552473 -0.110498 -0.532014  0.263131 -0.224011
# 106572     155319   -0.176901  0.187208 -0.050664  0.368843  0.066005
# 106573     155320    0.489665  1.862421  0.854461 -0.103666 -0.249835
#
# ...

# %%
features.describe()
# Out:
#              feature    chroma_cens                                \
#           statistics       kurtosis
#               number             01             02             03
# count  106574.000000  106574.000000  106574.000000  106574.000000
# mean    79442.637435       0.439999       0.199756       0.334683
# std     44704.398384      32.285524      11.120903       9.980692
# min         2.000000      -1.955806      -1.936607      -1.967450
# 25%     40820.250000      -0.636597      -0.665684      -0.629114
# 50%     78983.500000      -0.176557      -0.221131      -0.152708
# 75%    119422.750000       0.485000       0.410097       0.529836
# max    155320.000000    8843.367188    2864.075195    1777.615967
#
#                                                                    \
#
#                   04             05             06             07
# count  106574.000000  106574.000000  106574.000000  106574.000000
# mean        0.270263       0.294806       0.315635       0.273511
# ...

# %%
features['tonnetz']
# Out:
#                    kurtosis                                            \
#                          01                   02                   03
#        Unnamed: 470_level_3 Unnamed: 471_level_3 Unnamed: 472_level_3
# 0                  2.303301             0.978718             1.033038
# 1                  2.003829             1.376126             0.865467
# 2                 10.772251             0.921786            -0.189319
# 3                  0.500884             2.949731             0.088048
# 4                  1.112185             4.171312             0.250815
# ...                     ...                  ...                  ...
# 106569             1.918674             0.398204             0.365857
# 106570             0.502625             1.043272            -0.169809
# 106571             0.643009             1.461457             0.290750
# 106572             0.304471             0.189150             0.737512
# ...

# %%
features = features.droplevel(-1, axis=1)

# %%
features['chroma_cens']
# Out:
#         kurtosis                                                              \
#               01        02        03        04        05        06        07
# 0       7.180653  5.230309  0.249321  1.347620  1.482478  0.531371  1.481593
# 1       1.888963  0.760539  0.345297  2.295201  1.654031  0.067592  1.366848
# 2       0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839 -0.923192
# 3       3.702245 -0.291193  2.196742 -0.234449  1.367364  0.998411  1.770694
# 4      -0.193837 -0.198527  0.201546  0.258556  0.775204  0.084794 -0.289294
# ...          ...       ...       ...       ...       ...       ...       ...
# 106569 -0.490129  0.463834  2.321970 -0.084352  1.662914  2.115189 -0.237794
# 106570 -0.461559 -0.229601 -0.496632 -0.422033  0.130612 -0.263825 -0.628103
# 106571  0.552473 -0.110498 -0.532014  0.263131 -0.224011 -0.530972  1.713526
# 106572 -0.176901  0.187208 -0.050664  0.368843  0.066005 -0.857354 -0.780860
# ...

# %%
col_feat = features.columns
col_feat
# Out:
# MultiIndex([(    'feature', 'statistics', 'number'),
#             ('chroma_cens',   'kurtosis',     '01'),
#             ('chroma_cens',   'kurtosis',     '02'),
#             ('chroma_cens',   'kurtosis',     '03'),
#             ('chroma_cens',   'kurtosis',     '04'),
#             ('chroma_cens',   'kurtosis',     '05'),
#             ('chroma_cens',   'kurtosis',     '06'),
#             ('chroma_cens',   'kurtosis',     '07'),
#             ('chroma_cens',   'kurtosis',     '08'),
#             ('chroma_cens',   'kurtosis',     '09'),
#             ...
#             (    'tonnetz',        'std',     '04'),
#             (    'tonnetz',        'std',     '05'),
#             (    'tonnetz',        'std',     '06'),
#             (        'zcr',   'kurtosis',     '01'),
#             (        'zcr',        'max',     '01'),
#             (        'zcr',       'mean',     '01'),
#             (        'zcr',     'median',     '01'),
# ...

# %% [markdown]
# # Preproc

# %% [markdown]
# tr
